# %%
from matplotlib import image
from matplotlib import pyplot
image = image.imread('einstein.jpg')
print(image.dtype)
print(image.shape)
pyplot.imshow(image)
pyplot.show()
# Out:
# uint8
# (182, 186, 3)

# %%
image
# Out:
# array([[[255, 255, 255],
#         [248, 248, 248],
#         [255, 255, 255],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[244, 244, 244],
#         [254, 254, 254],
#         [235, 235, 235],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [247, 247, 247],
#         [ 90,  90,  90],
#         ...,
#         [138, 138, 138],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [244, 244, 244],
#         [ 98,  98,  98],
#         ...,
#         [101, 101, 101],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[236, 236, 236],
#         [255, 255, 255],
#         [232, 232, 232],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [245, 245, 245],
# ...

# %%
import numpy as np
mini=float("inf")
for i in image:
    for j in i:
        if(mini>min(j)):
            mini=min(j)

# %%
q=4
mini
# Out:
# 0

# %%
arr=[64,32,16,4]

# %%
import math

# %%
img64=((image-mini)//q)*q+(q//2)+mini
pyplot.imshow(img64)

# %%
error=(img-img64)**2
s=0
print(np.mean(error))
# Out:
# 1.487770294221907
# 564

# %%
q=(2**8)//32
print(q)
img32=((image-mini)//q)*q+(q//2)+mini
pyplot.imshow(img32)
# Out:
# 8

# %%
error=(img-img32)**2
s=0
print(np.mean(error))
# Out:
# 5.544015124660286

# %%
q=(2**8)//16
print(q)
img16=((image-mini)//q)*q+(q//2)+mini
pyplot.imshow(img16)
# Out:
# 16

# %%
error=(img-img16)**2
s=0
print(np.mean(error))
# Out:
# 21.850762141084722

# %%
q=(2**8)//4
print(q)
img4=((image-mini)//q)*q+(q//2)+mini
pyplot.imshow(img4)
# Out:
# 64

# %%
error=(img-img4)**2
s=0
print(np.mean(error))
# Out:
# 94.71570365118752

# %%
from PIL import Image  
import PIL  
  
im1 = Image.open('einstein.jpg')  
im1 = im1.quantize(64) 
im1
# Out:
# <PIL.Image.Image image mode=P size=186x182 at 0x21A123FFB88>

# %%
im1 = im1.quantize(32) 
im1
# Out:
# <PIL.Image.Image image mode=P size=186x182 at 0x21A12427708>

# %%
im1 = im1.quantize(16) 
im1
# Out:
# <PIL.Image.Image image mode=P size=186x182 at 0x21A12427148>

# %%
im1 = im1.quantize(4) 
im1
# Out:
# <PIL.Image.Image image mode=P size=186x182 at 0x21A1242F408>

# %%
import cv2 
im_gray = cv2.imread('einstein.jpg') 
pyplot.imshow(im_gray)

# (thresh, im_bw) = cv2.threshold(im_gray, 128, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU) 
# thresh = 127 
# im_binary = cv2.threshold(im_gray, thresh, 255, cv 
# cv2.imwrite('binary_image.png', im_bw)

# %%
(thresh, blackAndWhiteImage) = cv2.threshold(im_gray, 127, 255, cv2.THRESH_BINARY)

# %%
pyplot.imshow(blackAndWhiteImage)

# %%
img1 = cv2.imread('einstein.jpg')
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
bw_img = cv2.threshold(img1,127,255,cv2.THRESH_BINARY)[1]

# %%
# a) Euclidean distance
dst_euc = cv2.distanceTransform(bw_img,cv2.DIST_L1, 3)
dst_euc
# Out:
# array([[4., 3., 2., ..., 6., 7., 8.],
#        [3., 2., 1., ..., 5., 6., 7.],
#        [2., 1., 0., ..., 4., 5., 6.],
#        ...,
#        [2., 1., 0., ..., 0., 1., 2.],
#        [3., 2., 1., ..., 1., 2., 3.],
#        [4., 3., 2., ..., 2., 3., 4.]], dtype=float32)

# %%
pyplot.imshow(dst_euc)

# %%
dst_euc = cv2.distanceTransform(bw_img,cv2.DIST_C, 3)
pyplot.imshow(dst_euc)

# %%
dst_euc = cv2.distanceTransform(bw_img,cv2.DIST_L2, 3)
pyplot.imshow(dst_euc)

# %%
dst_euc = cv2.distanceTransform(bw_img,cv2.DIST_LABEL_PIXEL, 3)
pyplot.imshow(dst_euc)

# %%
dst_euc = cv2.distanceTransform(bw_img,cv2.DIST_MASK_3, 3)
pyplot.imshow(dst_euc)

# %%
import cv2 
import numpy as np 
img = cv2.imread('einstein.jpg', 0) 
m, n = img.shape 
mask = np.ones([3, 3], dtype = int) 
mask = mask / 9
img_new = np.zeros([m, n]) 
  
for i in range(1, m-1): 
    for j in range(1, n-1): 
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2] 
         
        img_new[i, j]= temp 
          
img_new = img_new.astype(np.uint8) 
pyplot.imshow(img_new)

# %%
import cv2 
import numpy as np 
img = cv2.imread('einstein.jpg', 0) 
m, n = img.shape 
mask = np.ones([5, 5], dtype = int) 
mask = mask / 9
img_new = np.zeros([m, n]) 
  
for i in range(1, m-1): 
    for j in range(1, n-1): 
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2] 
         
        img_new[i, j]= temp 
          
img_new = img_new.astype(np.uint8) 
pyplot.imshow(img_new)

# %%
import cv2 
import numpy as np 
img = cv2.imread('einstein.jpg', 0) 
m, n = img.shape 
mask = np.ones([7,7], dtype = int) 
mask = mask / 9
img_new = np.zeros([m, n]) 
  
for i in range(1, m-1): 
    for j in range(1, n-1): 
        temp = img[i-1, j-1]*mask[0, 0]+img[i-1, j]*mask[0, 1]+img[i-1, j + 1]*mask[0, 2]+img[i, j-1]*mask[1, 0]+ img[i, j]*mask[1, 1]+img[i, j + 1]*mask[1, 2]+img[i + 1, j-1]*mask[2, 0]+img[i + 1, j]*mask[2, 1]+img[i + 1, j + 1]*mask[2, 2] 
         
        img_new[i, j]= temp 
          
img_new = img_new.astype(np.uint8) 
pyplot.imshow(img_new)
